# %%
import pandas as pd


OpenFile = pd.read_csv('diabetes_prediction_dataset - Copy.csv')
#print(OpenFile)

# Group and count values in the 'gender'
#count_gender = df.groupby('gender').size().reset_index(name='count')
#count_smoker = df.groupby('smoking_history').size().reset_index(name='count')

#print(count_smoker)


# Define the mapping dictionary for gender values
gender_mapping = {'Male': 0, 'Female': 1,}

# Map the gender values using the mapping dictionary
OpenFile['gender'] = OpenFile['gender'].map(gender_mapping)

print(OpenFile.head(30))

CheckData = OpenFile.info()
# Out:
#     gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      1.0  80.0             0              1           never  25.19
# 1      1.0  54.0             0              0         No Info  27.32
# 2      0.0  28.0             0              0           never  27.32
# 3      1.0  36.0             0              0         current  23.45
# 4      0.0  76.0             1              1         current  20.14
# 5      1.0  20.0             0              0           never  27.32
# 6      1.0  44.0             0              0           never  19.31
# 7      1.0  79.0             0              0         No Info  23.86
# 8      0.0  42.0             0              0           never  33.64
# 9      1.0  32.0             0              0           never  27.32
# 10     1.0  53.0             0              0           never  27.32
# 11     1.0  54.0             0              0          former  54.70
# 12     1.0  78.0             0              0          former  36.05
# ...

# %%
# Check empty cells
CheckNull = OpenFile.isnull().sum()
print(CheckNull)
